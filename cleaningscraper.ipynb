# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gym.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1           1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2           2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3           3                                       Push Up Bars
# 4           4  Roller Perfect Abdominal and Stomach Exercise ...
#
#                                               images  \
# 0  ['https://www.facebook.com/tr?id=1350000625395...
# 1  ['https://www.facebook.com/tr?id=1350000625395...
# 2  ['https://www.facebook.com/tr?id=1350000625395...
# 3  ['https://www.facebook.com/tr?id=1350000625395...
# 4  ['https://www.facebook.com/tr?id=1350000625395...
#
#                                          description      price     rating  \
# 0  Materaial: Rubber\nPair of Neoprene coated Dum...   रू 9,999  no rating
# 1  Material: Bumper Plate Rubber with non-slip ru...   रू 9,999  no rating
# 2  This Dumbbell and Barbell set is perfect for y...  रू 14,999  no rating
# 3  Product details of Push Up Bars\n\n\n\nConvini...   रू 1,799  no rating
# 4  ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...     रू 999  no rating
#
#       review
# 0  no review
# 1  no review
# 2  no review
# 3  no review
# 4  no review

# %%
df[['images', 'img1']] = df['images'].str.split(',', 1, expand=True)

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1             1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2             2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3             3                                       Push Up Bars
# 4             4  Roller Perfect Abdominal and Stomach Exercise ...
# ..          ...                                                ...
# 175         175                                            no name
# 176         176                            Pretorian Boxing Gloves
# 177         177                                  BIN Boxing Gloves
# 178         178                       3 Station Home Gyms - MS632S
# 179         179             3 Station Home Gym - With Punching Bag
#
#                                                 images  \
# 0    ['https://www.facebook.com/tr?id=1350000625395...
# 1    ['https://www.facebook.com/tr?id=1350000625395...
# 2    ['https://www.facebook.com/tr?id=1350000625395...
# 3    ['https://www.facebook.com/tr?id=1350000625395...
# 4    ['https://www.facebook.com/tr?id=1350000625395...
# ..                                                 ...
# 175  ['https://www.facebook.com/tr?id=1350000625395...
# 176  ['https://www.facebook.com/tr?id=1350000625395...
# 177  ['https://www.facebook.com/tr?id=1350000625395...
# 178  ['https://www.facebook.com/tr?id=1350000625395...
# 179  ['https://www.facebook.com/tr?id=1350000625395...
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                               img1
# 0    no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 1    no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 2    no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 3    no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 4    no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# ..         ...                                                ...
# 175  no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 176  no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 177  no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 178  no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
# 179  no review   'https://cdn.sastodeal.com/fb_1.png', 'https:...
#
# [180 rows x 8 columns]

# %%
df[['img1', 'img2']] = df['img1'].str.split(',', 1, expand=True)
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1             1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2             2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3             3                                       Push Up Bars
# 4             4  Roller Perfect Abdominal and Stomach Exercise ...
# ..          ...                                                ...
# 175         175                                            no name
# 176         176                            Pretorian Boxing Gloves
# 177         177                                  BIN Boxing Gloves
# 178         178                       3 Station Home Gyms - MS632S
# 179         179             3 Station Home Gym - With Punching Bag
#
#                                                 images  \
# 0    ['https://www.facebook.com/tr?id=1350000625395...
# 1    ['https://www.facebook.com/tr?id=1350000625395...
# 2    ['https://www.facebook.com/tr?id=1350000625395...
# 3    ['https://www.facebook.com/tr?id=1350000625395...
# 4    ['https://www.facebook.com/tr?id=1350000625395...
# ..                                                 ...
# 175  ['https://www.facebook.com/tr?id=1350000625395...
# 176  ['https://www.facebook.com/tr?id=1350000625395...
# 177  ['https://www.facebook.com/tr?id=1350000625395...
# 178  ['https://www.facebook.com/tr?id=1350000625395...
# 179  ['https://www.facebook.com/tr?id=1350000625395...
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                   img1  \
# 0    no review   'https://cdn.sastodeal.com/fb_1.png'
# 1    no review   'https://cdn.sastodeal.com/fb_1.png'
# 2    no review   'https://cdn.sastodeal.com/fb_1.png'
# 3    no review   'https://cdn.sastodeal.com/fb_1.png'
# 4    no review   'https://cdn.sastodeal.com/fb_1.png'
# ..         ...                                    ...
# 175  no review   'https://cdn.sastodeal.com/fb_1.png'
# 176  no review   'https://cdn.sastodeal.com/fb_1.png'
# 177  no review   'https://cdn.sastodeal.com/fb_1.png'
# 178  no review   'https://cdn.sastodeal.com/fb_1.png'
# 179  no review   'https://cdn.sastodeal.com/fb_1.png'
#
#                                                   img2
# 0     'https://cdn.sastodeal.com/insta.png', 'https...
# 1     'https://cdn.sastodeal.com/insta.png', 'https...
# 2     'https://cdn.sastodeal.com/insta.png', 'https...
# 3     'https://cdn.sastodeal.com/insta.png', 'https...
# 4     'https://cdn.sastodeal.com/insta.png', 'https...
# ..                                                 ...
# 175   'https://cdn.sastodeal.com/insta.png', 'https...
# 176   'https://cdn.sastodeal.com/insta.png', 'https...
# 177   'https://cdn.sastodeal.com/insta.png', 'https...
# 178   'https://cdn.sastodeal.com/insta.png', 'https...
# 179   'https://cdn.sastodeal.com/insta.png', 'https...
#
# [180 rows x 9 columns]

# %%
df[['img2', 'img3']] = df['img2'].str.split(',', 1, expand=True)
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1             1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2             2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3             3                                       Push Up Bars
# 4             4  Roller Perfect Abdominal and Stomach Exercise ...
# ..          ...                                                ...
# 175         175                                            no name
# 176         176                            Pretorian Boxing Gloves
# 177         177                                  BIN Boxing Gloves
# 178         178                       3 Station Home Gyms - MS632S
# 179         179             3 Station Home Gym - With Punching Bag
#
#                                                 images  \
# 0    ['https://www.facebook.com/tr?id=1350000625395...
# 1    ['https://www.facebook.com/tr?id=1350000625395...
# 2    ['https://www.facebook.com/tr?id=1350000625395...
# 3    ['https://www.facebook.com/tr?id=1350000625395...
# 4    ['https://www.facebook.com/tr?id=1350000625395...
# ..                                                 ...
# 175  ['https://www.facebook.com/tr?id=1350000625395...
# 176  ['https://www.facebook.com/tr?id=1350000625395...
# 177  ['https://www.facebook.com/tr?id=1350000625395...
# 178  ['https://www.facebook.com/tr?id=1350000625395...
# 179  ['https://www.facebook.com/tr?id=1350000625395...
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                   img1  \
# 0    no review   'https://cdn.sastodeal.com/fb_1.png'
# 1    no review   'https://cdn.sastodeal.com/fb_1.png'
# 2    no review   'https://cdn.sastodeal.com/fb_1.png'
# 3    no review   'https://cdn.sastodeal.com/fb_1.png'
# 4    no review   'https://cdn.sastodeal.com/fb_1.png'
# ..         ...                                    ...
# 175  no review   'https://cdn.sastodeal.com/fb_1.png'
# 176  no review   'https://cdn.sastodeal.com/fb_1.png'
# 177  no review   'https://cdn.sastodeal.com/fb_1.png'
# 178  no review   'https://cdn.sastodeal.com/fb_1.png'
# 179  no review   'https://cdn.sastodeal.com/fb_1.png'
#
#                                        img2  \
# 0     'https://cdn.sastodeal.com/insta.png'
# 1     'https://cdn.sastodeal.com/insta.png'
# 2     'https://cdn.sastodeal.com/insta.png'
# 3     'https://cdn.sastodeal.com/insta.png'
# 4     'https://cdn.sastodeal.com/insta.png'
# ..                                      ...
# 175   'https://cdn.sastodeal.com/insta.png'
# 176   'https://cdn.sastodeal.com/insta.png'
# 177   'https://cdn.sastodeal.com/insta.png'
# 178   'https://cdn.sastodeal.com/insta.png'
# 179   'https://cdn.sastodeal.com/insta.png'
#
#                                                   img3
# 0     'https://cdn.sastodeal.com/twitter.png', 'htt...
# 1     'https://cdn.sastodeal.com/twitter.png', 'htt...
# 2     'https://cdn.sastodeal.com/twitter.png', 'htt...
# 3     'https://cdn.sastodeal.com/twitter.png', 'htt...
# 4     'https://cdn.sastodeal.com/twitter.png', 'htt...
# ..                                                 ...
# 175   'https://cdn.sastodeal.com/twitter.png', 'htt...
# 176   'https://cdn.sastodeal.com/twitter.png', 'htt...
# 177   'https://cdn.sastodeal.com/twitter.png', 'htt...
# 178   'https://cdn.sastodeal.com/twitter.png', 'htt...
# 179   'https://cdn.sastodeal.com/twitter.png', 'htt...
#
# [180 rows x 10 columns]

# %%
df[['img3', 'img4']] = df['img3'].str.split(',', 1, expand=True)
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1             1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2             2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3             3                                       Push Up Bars
# 4             4  Roller Perfect Abdominal and Stomach Exercise ...
# ..          ...                                                ...
# 175         175                                            no name
# 176         176                            Pretorian Boxing Gloves
# 177         177                                  BIN Boxing Gloves
# 178         178                       3 Station Home Gyms - MS632S
# 179         179             3 Station Home Gym - With Punching Bag
#
#                                                 images  \
# 0    ['https://www.facebook.com/tr?id=1350000625395...
# 1    ['https://www.facebook.com/tr?id=1350000625395...
# 2    ['https://www.facebook.com/tr?id=1350000625395...
# 3    ['https://www.facebook.com/tr?id=1350000625395...
# 4    ['https://www.facebook.com/tr?id=1350000625395...
# ..                                                 ...
# 175  ['https://www.facebook.com/tr?id=1350000625395...
# 176  ['https://www.facebook.com/tr?id=1350000625395...
# 177  ['https://www.facebook.com/tr?id=1350000625395...
# 178  ['https://www.facebook.com/tr?id=1350000625395...
# 179  ['https://www.facebook.com/tr?id=1350000625395...
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                   img1  \
# 0    no review   'https://cdn.sastodeal.com/fb_1.png'
# 1    no review   'https://cdn.sastodeal.com/fb_1.png'
# 2    no review   'https://cdn.sastodeal.com/fb_1.png'
# 3    no review   'https://cdn.sastodeal.com/fb_1.png'
# 4    no review   'https://cdn.sastodeal.com/fb_1.png'
# ..         ...                                    ...
# 175  no review   'https://cdn.sastodeal.com/fb_1.png'
# 176  no review   'https://cdn.sastodeal.com/fb_1.png'
# 177  no review   'https://cdn.sastodeal.com/fb_1.png'
# 178  no review   'https://cdn.sastodeal.com/fb_1.png'
# 179  no review   'https://cdn.sastodeal.com/fb_1.png'
#
#                                        img2  \
# 0     'https://cdn.sastodeal.com/insta.png'
# 1     'https://cdn.sastodeal.com/insta.png'
# 2     'https://cdn.sastodeal.com/insta.png'
# 3     'https://cdn.sastodeal.com/insta.png'
# 4     'https://cdn.sastodeal.com/insta.png'
# ..                                      ...
# 175   'https://cdn.sastodeal.com/insta.png'
# 176   'https://cdn.sastodeal.com/insta.png'
# 177   'https://cdn.sastodeal.com/insta.png'
# 178   'https://cdn.sastodeal.com/insta.png'
# 179   'https://cdn.sastodeal.com/insta.png'
#
#                                          img3  \
# 0     'https://cdn.sastodeal.com/twitter.png'
# 1     'https://cdn.sastodeal.com/twitter.png'
# 2     'https://cdn.sastodeal.com/twitter.png'
# 3     'https://cdn.sastodeal.com/twitter.png'
# 4     'https://cdn.sastodeal.com/twitter.png'
# ..                                        ...
# 175   'https://cdn.sastodeal.com/twitter.png'
# 176   'https://cdn.sastodeal.com/twitter.png'
# 177   'https://cdn.sastodeal.com/twitter.png'
# 178   'https://cdn.sastodeal.com/twitter.png'
# 179   'https://cdn.sastodeal.com/twitter.png'
#
#                                                   img4
# 0     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 1     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 2     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 3     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 4     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# ..                                                 ...
# 175   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 176   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 177   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 178   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 179   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
#
# [180 rows x 11 columns]

# %%
df[['img4', 'img5']] = df['img4'].str.split(',', 1, expand=True)
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1             1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2             2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3             3                                       Push Up Bars
# 4             4  Roller Perfect Abdominal and Stomach Exercise ...
# ..          ...                                                ...
# 175         175                                            no name
# 176         176                            Pretorian Boxing Gloves
# 177         177                                  BIN Boxing Gloves
# 178         178                       3 Station Home Gyms - MS632S
# 179         179             3 Station Home Gym - With Punching Bag
#
#                                                 images  \
# 0    ['https://www.facebook.com/tr?id=1350000625395...
# 1    ['https://www.facebook.com/tr?id=1350000625395...
# 2    ['https://www.facebook.com/tr?id=1350000625395...
# 3    ['https://www.facebook.com/tr?id=1350000625395...
# 4    ['https://www.facebook.com/tr?id=1350000625395...
# ..                                                 ...
# 175  ['https://www.facebook.com/tr?id=1350000625395...
# 176  ['https://www.facebook.com/tr?id=1350000625395...
# 177  ['https://www.facebook.com/tr?id=1350000625395...
# 178  ['https://www.facebook.com/tr?id=1350000625395...
# 179  ['https://www.facebook.com/tr?id=1350000625395...
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                   img1  \
# 0    no review   'https://cdn.sastodeal.com/fb_1.png'
# 1    no review   'https://cdn.sastodeal.com/fb_1.png'
# 2    no review   'https://cdn.sastodeal.com/fb_1.png'
# 3    no review   'https://cdn.sastodeal.com/fb_1.png'
# 4    no review   'https://cdn.sastodeal.com/fb_1.png'
# ..         ...                                    ...
# 175  no review   'https://cdn.sastodeal.com/fb_1.png'
# 176  no review   'https://cdn.sastodeal.com/fb_1.png'
# 177  no review   'https://cdn.sastodeal.com/fb_1.png'
# 178  no review   'https://cdn.sastodeal.com/fb_1.png'
# 179  no review   'https://cdn.sastodeal.com/fb_1.png'
#
#                                        img2  \
# 0     'https://cdn.sastodeal.com/insta.png'
# 1     'https://cdn.sastodeal.com/insta.png'
# 2     'https://cdn.sastodeal.com/insta.png'
# 3     'https://cdn.sastodeal.com/insta.png'
# 4     'https://cdn.sastodeal.com/insta.png'
# ..                                      ...
# 175   'https://cdn.sastodeal.com/insta.png'
# 176   'https://cdn.sastodeal.com/insta.png'
# 177   'https://cdn.sastodeal.com/insta.png'
# 178   'https://cdn.sastodeal.com/insta.png'
# 179   'https://cdn.sastodeal.com/insta.png'
#
#                                          img3  \
# 0     'https://cdn.sastodeal.com/twitter.png'
# 1     'https://cdn.sastodeal.com/twitter.png'
# 2     'https://cdn.sastodeal.com/twitter.png'
# 3     'https://cdn.sastodeal.com/twitter.png'
# 4     'https://cdn.sastodeal.com/twitter.png'
# ..                                        ...
# 175   'https://cdn.sastodeal.com/twitter.png'
# 176   'https://cdn.sastodeal.com/twitter.png'
# 177   'https://cdn.sastodeal.com/twitter.png'
# 178   'https://cdn.sastodeal.com/twitter.png'
# 179   'https://cdn.sastodeal.com/twitter.png'
#
#                                                   img4  \
# 0     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 1     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 2     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 3     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 4     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# ..                                                 ...
# 175   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 176   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 177   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 178   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 179   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
#
#                                                   img5
# 0     'https://cdn.sastodeal.com/catalog/product/1/...
# 1     'https://cdn.sastodeal.com/catalog/product/1/...
# 2     'https://cdn.sastodeal.com/catalog/product/1/...
# 3     'https://cdn.sastodeal.com/catalog/product/1/...
# 4     'https://cdn.sastodeal.com/catalog/product/1/...
# ..                                                 ...
# 175   'https://cdn.sastodeal.com/catalog/product/1/...
# 176   'https://cdn.sastodeal.com/catalog/product/1/...
# 177   'https://cdn.sastodeal.com/catalog/product/1/...
# 178   'https://cdn.sastodeal.com/catalog/product/1/...
# 179   'https://cdn.sastodeal.com/catalog/product/1/...
#
# [180 rows x 12 columns]

# %%
df[['img5', 'img6']] = df['img5'].str.split(',', 1, expand=True)
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1             1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2             2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3             3                                       Push Up Bars
# 4             4  Roller Perfect Abdominal and Stomach Exercise ...
# ..          ...                                                ...
# 175         175                                            no name
# 176         176                            Pretorian Boxing Gloves
# 177         177                                  BIN Boxing Gloves
# 178         178                       3 Station Home Gyms - MS632S
# 179         179             3 Station Home Gym - With Punching Bag
#
#                                                 images  \
# 0    ['https://www.facebook.com/tr?id=1350000625395...
# 1    ['https://www.facebook.com/tr?id=1350000625395...
# 2    ['https://www.facebook.com/tr?id=1350000625395...
# 3    ['https://www.facebook.com/tr?id=1350000625395...
# 4    ['https://www.facebook.com/tr?id=1350000625395...
# ..                                                 ...
# 175  ['https://www.facebook.com/tr?id=1350000625395...
# 176  ['https://www.facebook.com/tr?id=1350000625395...
# 177  ['https://www.facebook.com/tr?id=1350000625395...
# 178  ['https://www.facebook.com/tr?id=1350000625395...
# 179  ['https://www.facebook.com/tr?id=1350000625395...
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                   img1  \
# 0    no review   'https://cdn.sastodeal.com/fb_1.png'
# 1    no review   'https://cdn.sastodeal.com/fb_1.png'
# 2    no review   'https://cdn.sastodeal.com/fb_1.png'
# 3    no review   'https://cdn.sastodeal.com/fb_1.png'
# 4    no review   'https://cdn.sastodeal.com/fb_1.png'
# ..         ...                                    ...
# 175  no review   'https://cdn.sastodeal.com/fb_1.png'
# 176  no review   'https://cdn.sastodeal.com/fb_1.png'
# 177  no review   'https://cdn.sastodeal.com/fb_1.png'
# 178  no review   'https://cdn.sastodeal.com/fb_1.png'
# 179  no review   'https://cdn.sastodeal.com/fb_1.png'
#
#                                        img2  \
# 0     'https://cdn.sastodeal.com/insta.png'
# 1     'https://cdn.sastodeal.com/insta.png'
# 2     'https://cdn.sastodeal.com/insta.png'
# 3     'https://cdn.sastodeal.com/insta.png'
# 4     'https://cdn.sastodeal.com/insta.png'
# ..                                      ...
# 175   'https://cdn.sastodeal.com/insta.png'
# 176   'https://cdn.sastodeal.com/insta.png'
# 177   'https://cdn.sastodeal.com/insta.png'
# 178   'https://cdn.sastodeal.com/insta.png'
# 179   'https://cdn.sastodeal.com/insta.png'
#
#                                          img3  \
# 0     'https://cdn.sastodeal.com/twitter.png'
# 1     'https://cdn.sastodeal.com/twitter.png'
# 2     'https://cdn.sastodeal.com/twitter.png'
# 3     'https://cdn.sastodeal.com/twitter.png'
# 4     'https://cdn.sastodeal.com/twitter.png'
# ..                                        ...
# 175   'https://cdn.sastodeal.com/twitter.png'
# 176   'https://cdn.sastodeal.com/twitter.png'
# 177   'https://cdn.sastodeal.com/twitter.png'
# 178   'https://cdn.sastodeal.com/twitter.png'
# 179   'https://cdn.sastodeal.com/twitter.png'
#
#                                                   img4  \
# 0     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 1     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 2     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 3     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 4     'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# ..                                                 ...
# 175   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 176   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 177   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 178   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
# 179   'https://cdn.sastodeal.com/logo/stores/1/SDLo...
#
#                                                   img5  \
# 0     'https://cdn.sastodeal.com/catalog/product/1/...
# 1     'https://cdn.sastodeal.com/catalog/product/1/...
# 2     'https://cdn.sastodeal.com/catalog/product/1/...
# 3     'https://cdn.sastodeal.com/catalog/product/1/...
# 4     'https://cdn.sastodeal.com/catalog/product/1/...
# ..                                                 ...
# 175   'https://cdn.sastodeal.com/catalog/product/1/...
# 176   'https://cdn.sastodeal.com/catalog/product/1/...
# 177   'https://cdn.sastodeal.com/catalog/product/1/...
# 178   'https://cdn.sastodeal.com/catalog/product/1/...
# 179   'https://cdn.sastodeal.com/catalog/product/1/...
#
#                                                   img6
# 0     'https://www.sastodeal.com/static/version1647...
# 1     'https://www.sastodeal.com/static/version1647...
# 2     'https://www.sastodeal.com/static/version1647...
# 3     'https://www.sastodeal.com/static/version1647...
# 4     'https://www.sastodeal.com/static/version1647...
# ..                                                 ...
# 175   'https://www.sastodeal.com/static/version1647...
# 176   'https://www.sastodeal.com/static/version1647...
# 177   'https://www.sastodeal.com/static/version1647...
# 178   'https://www.sastodeal.com/static/version1647...
# 179   'https://www.sastodeal.com/static/version1647...
#
# [180 rows x 13 columns]

# %%
df.drop(['images', 'img1','img2','img3','img4','img6'], axis=1, inplace=True)

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1             1  Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2             2  Adjustable Dumbbell Barbell Weight Lifting Set...
# 3             3                                       Push Up Bars
# 4             4  Roller Perfect Abdominal and Stomach Exercise ...
# ..          ...                                                ...
# 175         175                                            no name
# 176         176                            Pretorian Boxing Gloves
# 177         177                                  BIN Boxing Gloves
# 178         178                       3 Station Home Gyms - MS632S
# 179         179             3 Station Home Gym - With Punching Bag
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                               img5
# 0    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 1    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 2    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 3    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 4    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# ..         ...                                                ...
# 175  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 176  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 177  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 178  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 179  no review   'https://cdn.sastodeal.com/catalog/product/1/...
#
# [180 rows x 7 columns]

# %%
df.drop(df.columns[[0]], axis=1, inplace=True)

# %%
df
# Out:
#                                                  title  \
# 0    Dumbbell Set 10Kg Dumbbells Hand Weights Free ...
# 1    Dumbell 10Kg / 15Kg / 20Kg Adjustable Top Grad...
# 2    Adjustable Dumbbell Barbell Weight Lifting Set...
# 3                                         Push Up Bars
# 4    Roller Perfect Abdominal and Stomach Exercise ...
# ..                                                 ...
# 175                                            no name
# 176                            Pretorian Boxing Gloves
# 177                                  BIN Boxing Gloves
# 178                       3 Station Home Gyms - MS632S
# 179             3 Station Home Gym - With Punching Bag
#
#                                            description       price     rating  \
# 0    Materaial: Rubber\nPair of Neoprene coated Dum...    रू 9,999  no rating
# 1    Material: Bumper Plate Rubber with non-slip ru...    रू 9,999  no rating
# 2    This Dumbbell and Barbell set is perfect for y...   रू 14,999  no rating
# 3    Product details of Push Up Bars\n\n\n\nConvini...    रू 1,799  no rating
# 4    ✮CORE TRAINING ✮ - Izoo Ab roller acts as your...      रू 999  no rating
# ..                                                 ...         ...        ...
# 175                                     no description    no price  no rating
# 176  About Product :\nThese gloves offer maximum pr...    रू 3,750  no rating
# 177  BIN Boxing Gloves :\nThese gloves offer maximu...    रू 3,750  no rating
# 178  Product Description :\nThe MS632S is an awesom...  रू 130,000  no rating
# 179  MS631S Three-man Station Trainer\nProduct spec...  रू 130,000  no rating
#
#         review                                               img5
# 0    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 1    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 2    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 3    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 4    no review   'https://cdn.sastodeal.com/catalog/product/1/...
# ..         ...                                                ...
# 175  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 176  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 177  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 178  no review   'https://cdn.sastodeal.com/catalog/product/1/...
# 179  no review   'https://cdn.sastodeal.com/catalog/product/1/...
#
# [180 rows x 6 columns]

# %%
df.to_csv('datagy.csv')
